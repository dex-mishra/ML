# %% [markdown]
# <a href="https://colab.research.google.com/github/dex-mishra/ML/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_profiling

# %%
import sys
# !pip uninstall -y pandas_profiling numba > /dev/null
# !pip install ydata-profiling > /dev/null
from ydata_profiling import ProfileReport
# Out:
# WARNING: Skipping numba as it is not installed.
# /tmp/ipykernel_3497/2056800330.py:4: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("train.csv")

# %%
sns.scatterplot(style="Embarked",x="Age",y="Fare",hue="Survived",data=df,size="Pclass")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
prof = ProfileReport(df)
prof.to_file('output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
